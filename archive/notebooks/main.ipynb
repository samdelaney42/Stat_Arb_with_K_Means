# %%
from stat_arb_model import statarb
from stat_arb_clustering import clusters
from datetime import date
import pandas as pd
import numpy as np

# %%
path = '~/k_means/Data/sp_financials.csv'
c = clusters(path)
c.create()

# %%
c.generate_low_num_clusters(max_num_stocks = 10)
# Out:
# Clusters with <= 10 stocks:
# [3, 4, 5, 6, 8, 11, 12, 13, 16, 22, 23, 24]

# %%
c.generate_pairs(which_cluster = 11)
# Out:
# [['APA', 'ADSK'], ['APA', 'INCY'], ['ADSK', 'INCY']]

# %%
start = date(2016, 1, 1)
end = date.today()
name_1 = "APA"
name_2 = "INCY"

model = statarb(name_1, name_2, start, end, beta_lookback=100)

# %%
model.test_coint()
# Out:
# Spread is Cointegrated at 5% Significance Level

# %%
model.backtest_pair()
# Out:
# Spread is Cointegrated at 5% Significance Level

# %%
#################################################################
#       need to investigate Orthognal Distance Regression
#################################################################

start = date(2016, 1, 1)
end = date.today()
name_1 = "INCY"
name_2 = "APA"

model = statarb(name_1, name_2, start, end, beta_lookback = 100)

# %%
model.test_coint()
# Out:
# Spread is not Cointegrated

# %%
model.backtest_pair()
# Out:
# Spread is not Cointegrated
